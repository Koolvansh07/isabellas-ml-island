# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\koolv\Downloads\spotify-2023.csv",encoding='latin-1')

# %%
dataset.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
data = pd.DataFrame(dataset)

# %%
useless = ['track_name', 'artist_count','released_year','released_month','released_day','streams']
data = dataset.drop(columns = useless,axis = 1)

# %%
data.head()
# Out:
#      artist(s)_name  in_spotify_playlists  in_spotify_charts  \
# 0  Latto, Jung Kook                   553                147
# 1       Myke Towers                  1474                 48
# 2    Olivia Rodrigo                  1397                113
# 3      Taylor Swift                  7858                100
# 4         Bad Bunny                  3133                 50
#
#    in_apple_playlists  in_apple_charts in_deezer_playlists  in_deezer_charts  \
# 0                  43              263                  45                10
# 1                  48              126                  58                14
# 2                  94              207                  91                14
# 3                 116              207                 125                12
# 4                  84              133                  87                15
#
#   in_shazam_charts  bpm key   mode  danceability_%  valence_%  energy_%  \
# ...

# %%
X = data

y = dataset['streams']
y.head()
# Out:
# 0    141381703
# 1    133716286
# 2    140003974
# 3    800840817
# 4    303236322
# Name: streams, dtype: object

# %%
X_train, y_train, X_test, y_test = train_test_split(X,y, test_size=0.25, random_state= 0 )

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import OneHotEncoder
model = RandomForestRegressor(n_estimators=100,random_state=0)

# %%
post = (X_train.dtypes=='object')
object_cols = list(post[post].index)
print(object_cols)
# Out:
# ['artist(s)_name', 'in_deezer_playlists', 'in_shazam_charts', 'key', 'mode']

# %%
hoe = OneHotEncoder(handle_unknown= 'ignore')
hoe_train = pd.DataFrame(hoe.fit_transform(X_train['artist(s)_name', 'in_deezer_playlists', 'in_shazam_charts', 'key', 'mode']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\koolv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('artist(s)_name', 'in_deezer_playlists', 'in_shazam_charts', 'key', 'mode')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
model.fit(X_train,y_train)
pred = model.predict(X_test)
print(mean_absolute_error(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17340\365251786.py in ?()
# ----> 1 model.fit(X_train,y_train)
#       2 pred = model.predict(X_test)
#       3 print(mean_absolute_error(X_test,y_test))
#
# c:\Users\koolv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\koolv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     344         """
#     345         # Validate or convert input data
#     346         if issparse(y):
# ...
